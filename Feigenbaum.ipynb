# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def Feigenbaum(x,r):
    return(x*(1-x)*r)
def data(x0,R):
    XN=np.empty((1000,np.size(R)))
    j=0
    for r in R:
        #print(r)
        x=x0
        for i in range(0,1000):
            #print(x)
            xn=Feigenbaum(x,r)
            XN[i,j]=xn
            x=xn
        j=j+1
    return(XN)

# %%
R0=np.arange(0,4,0.0001)
Y=data(0.2,R0) 
print(Y)
F=np.transpose(Y)
# %matplotlib notebook
#fig = plt.figure(figsize=(6,5))
plt.plot(R0,F[:,-100:],'.',markersize=0.01)
plt.show()
plt.savefig("Feigenbaum.pdf")
# Out:
# [[0.00000000e+00 1.60000000e-05 3.20000000e-05 ... 6.39952000e-01
#   6.39968000e-01 6.39984000e-01]
#  [0.00000000e+00 1.59997440e-09 6.39979520e-09 ... 9.21584627e-01
#   9.21589754e-01 9.21594879e-01]
#  [0.00000000e+00 1.59997440e-13 1.27995903e-12 ... 2.89043930e-01
#   2.89033864e-01 2.89023808e-01]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.10947670e-01
#   9.08857944e-01 6.81243635e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 3.94523545e-01
#   3.31324159e-01 8.68581264e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 9.55427207e-01
#   8.86149534e-01 4.56579994e-01]]
# <img src="data:image/png;base64,..." width="640">
