# %%
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import numpy as np

# %%
def f1(y,u,z):
    return(((u-y)/r1+15.398*y+6.017*(abs(y+98.168)-abs(y-93.604)))/c1)
def f2(y,u,z):
    return(((y-u)/r1+z)/c2)
def f3(y,u,z):
    return(-u/l)

# %%
def rhs(s, v):
    x,y,z=v
    return [10*(y-x), 28*x-x*z-y, x*y-(8/3)*z]
sol=solve_ivp(rhs,[0,100],[1,1,1],t_eval=np.linspace(0,100,100000))
plt.plot(sol.y[0],sol.y[1])
plt.savefig("Lorenz.pdf")

# %%
# %matplotlib notebook
from mpl_toolkits import mplot3d
#fig = plt.figure(figsize=(48,40))
ax = plt.axes(projection='3d')
ax.plot3D(sol.y[0],sol.y[1] , sol.y[2], 'gray',markersize=0.00001)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()
plt.savefig("lorenz2.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def rhs(s, v):
    x,y,z=v
    return [-y-z, x+0.2*y, 0.2+z*(x-7)]
sol=solve_ivp(rhs,[0,100],[1,1,1],t_eval=np.linspace(0,100,100000))
fig = plt.figure(figsize=(24,20))
ax = plt.axes(projection='3d')
ax.plot3D(sol.y[0],sol.y[1] , sol.y[2], 'gray',markersize=0.00001)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.savefig("rossler.pdf")
# Out:
# <img src="data:image/png;base64,..." width="2400">

# %%
def h(x):
    m0=-1.27
    m1=-0.68
    return(m1*x+0.5*(m0-m1)*(np.absolute(x+1)-np.absolute(x-1)))
def rhs(s, v):
    x,y,z=v
    return [9*(y-x-h(x)), x-y+z, -14.87*y]
sol=solve_ivp(rhs,[0,100],[0,0,1],t_eval=np.linspace(0,100,100000))
#fig = plt.figure(figsize=(24,20))
ax = plt.axes(projection='3d')
ax.plot3D(sol.y[0],sol.y[1] , sol.y[2], 'gray',markersize=0.00001)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.savefig("chua.pdf")
#plt.plot(sol.t,sol.y[0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
def h(x):
    m0=-0.8
    m1=-0.5
    return(m1*x+0.5*(m0-m1)*(np.absolute(x+1)-np.absolute(x-1)))
def rhs(s, v):
    x,y,z=v
    return [9*(0.7*(y-x)-h(x)), 0.7*(x-y)+z, -7*y]
sol=solve_ivp(rhs,[0,100],[0,0,1],t_eval=np.linspace(0,100,100000))
#fig = plt.figure(figsize=(24,20))
ax = plt.axes(projection='3d')
ax.plot3D(sol.y[0],sol.y[1] , sol.y[2], 'gray',markersize=0.00001)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.savefig("chua2.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">
